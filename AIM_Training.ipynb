# %% [markdown]
# # Model Training For Automated Inventory

# %% [markdown]
# ## Install dependencies

# %%
# !nvidia-smi
# Out:
# Sun Aug 17 13:20:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Get Data from drive

# %%
# !python train_val_split.py --datapath="/content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/train_og" --train_pct=0.9
# Out:
# Created folder at /content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/train_og/data/train/images.
# Created folder at /content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/train_og/data/train/labels.
# Created folder at /content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/train_og/data/validation/images.
# Created folder at /content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/train_og/data/validation/labels.
# Number of image files: 680
# Number of annotation files: 680
# Images moving to train: 612
# Images moving to validation: 68

# %% [markdown]
# ## Train model

# %%
# !yolo detect train data=/content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/data.yaml model=yolo11s.pt epochs=60 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ## Run a prediction

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=/content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/train_og/data/validation/images/11_jpg.rf.19422a49733fccc7248fd2731eaa5bb7.jpg save=True
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,423,249 parameters, 0 gradients, 21.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/train_og/data/validation/images/11_jpg.rf.19422a49733fccc7248fd2731eaa5bb7.jpg: 640x640 15 Teas, 16.8ms
# Speed: 6.3ms preprocess, 16.8ms inference, 212.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=/content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/automated-inventory-monitoring/data/IMG20250414120806.jpg save=True
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,423,249 parameters, 0 gradients, 21.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/grozi-3.2k-testing.v1i.yolov11/automated-inventory-monitoring/data/IMG20250414120806.jpg: 480x640 1 Cereals, 74.0ms
# Speed: 4.5ms preprocess, 74.0ms inference, 187.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Download Model

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 8%)
#   adding: train/ (stored 0%)
#   adding: train/train_batch1.jpg (deflated 2%)
#   adding: train/BoxF1_curve.png (deflated 11%)
#   adding: train/val_batch2_pred.jpg (deflated 4%)
#   adding: train/results.csv (deflated 62%)
#   adding: train/train_batch2.jpg (deflated 1%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/best.pt (deflated 8%)
#   adding: train/weights/last.pt (deflated 8%)
#   adding: train/val_batch2_labels.jpg (deflated 4%)
#   adding: train/BoxPR_curve.png (deflated 15%)
#   adding: train/results.png (deflated 8%)
#   adding: train/val_batch0_pred.jpg (deflated 4%)
#   adding: train/args.yaml (deflated 52%)
#   adding: train/labels_correlogram.jpg (deflated 37%)
#   adding: train/train_batch1952.jpg (deflated 5%)
#   adding: train/confusion_matrix.png (deflated 16%)
#   adding: train/train_batch0.jpg (deflated 1%)
#   adding: train/BoxP_curve.png (deflated 11%)
# ...
